# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.normal(100, 5, 1000)

# %%
b = np.random.normal(80, 5, 1000)

# %%
bm_data = np.append(a, b)
np.random.shuffle(bm_data)

# %%
sns.displot(bm_data)
plt.xlim(60,120)
# Out:
# (60.0, 120.0)

# %% [markdown]
# Take 1000 samples with 2 elements.

# %%
bm_2 = bm_data.reshape(1000,2).mean(axis = 1)
sns.displot(bm_2)
plt.xlim(60,120)
# Out:
# (60.0, 120.0)

# %% [markdown]
# Take 500 samples with 4 elements.

# %%
bm_4 = bm_data.reshape(500,4).mean(axis = 1)
sns.displot(bm_4)
plt.xlim(60,120)
# Out:
# (60.0, 120.0)

# %% [markdown]
# Take 200 samples with 10 elements.

# %%
bm_10 = bm_data.reshape(200,10).mean(axis = 1)
sns.displot(bm_10)
plt.xlim(60,120)
# Out:
# (60.0, 120.0)

# %% [markdown]
# Take 100 samples with 20 elements.

# %%
bm_20 = bm_data.reshape(100,20).mean(axis = 1)
sns.displot(bm_20)
plt.xlim(60,120)
# Out:
# (60.0, 120.0)
