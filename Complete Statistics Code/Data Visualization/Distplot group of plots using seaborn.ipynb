# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\eli\\Desktop\\Piece_Dim.csv")
df.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
sns.displot(data = df, x = "Length", bins = 10, hue = "Operator")
plt.title("Histograms")
plt.show()

# %%
sns.displot(data = df, x = "Length", bins = 10, col = "Operator")
plt.show()

# %%
sns.displot(data = df, x = "Length", kind = "kde")
plt.show()

# %%
sns.displot(data = df, x = "Length", rug = True, kind = "kde")
plt.show()

# %%
sns.displot(data = df, x = "Length", rug = True, kind = "kde", hue = "Operator")
plt.show()

# %%
sns.displot(data = df, x = "Length", rug = True, kind = "ecdf")
plt.show()

# %%
sns.displot(data = df, x = "Length", kind = "hist", kde = True, rug = True)
plt.show()

# %%
sns.displot(data = df, x = "Length", y = "Width")
plt.show()

# %%
sns.displot(data = df, x = "Length", y = "Width", kind = "kde", fill = True)
plt.show()
